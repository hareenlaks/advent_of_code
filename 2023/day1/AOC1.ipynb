# %%
import re

def check_substring(sub_string, is_rare):

    value = -1
    if not sub_string:
        return value
    
    check_list = [('1','one'), ('2','two'), ('3','three'), ('4','four'), ('5','five'), ('6','six'), ('7','seven'), ('8','eight'), ('9','nine')]
        
    if(is_rare):
        index = -1
    else:
        index = len(sub_string)
    
    for (key,number) in check_list:
        if re.search(number,sub_string):
            if(is_rare):
                if(sub_string.rindex(number) > index):
                    index = sub_string.rindex(number)
                    value = key
            else:
                if(sub_string.index(number) < index):
                    index = sub_string.index(number)
                    value = key

    return value
       

def get_value(string_name):
    first = "0"
    second = "0"
        
    for element in string_name:
        if(element.isdigit()):
            first = check_substring(string_name[:string_name.index(element)], False)
            if(first == -1):
                first = element
            break
        if element == string_name[-1]:
            first = check_substring(string_name, False)
            if(first == -1):
                first = element
                
    for element in reversed(string_name):
        if(element.isdigit()):
            second = check_substring(string_name[string_name.rindex(element)+1:],True)
            if(second == -1):
                second = element
            break
            
        if element == string_name[0]:
            second = check_substring(string_name, True)
            if(second == -1):
                second = element
                
    return int(first + second)

sum_of_all = 0
file_name = "puzzle_input.txt"
file1 = open(file_name, 'r')
count = 0

while True:
    
    line = file1.readline()
    
    if not line:
        break
        
    count +=1
    extracted = get_value(line)
    print(f"{extracted} <- {line}")
    sum_of_all += extracted 

print(f"Extracted : {count}") 
print(f"Sum of all values : {sum_of_all}")
# Out:
# 44 <- 46threevqs8114
#
# 31 <- threetwoonez1gtrd
#
# 66 <- 6ffxbtff
#
# 79 <- 769twotwo6rv9
#
# 32 <- gjrcjrkvghthreegqqrg82qbct
#
# 88 <- zkxjhgprtrlcfeight795five8
#
# 95 <- 99seven3vdcgvmvxtjtwodc5
#
# 33 <- three5eightthree3four3vtkkqrgxs
#
# 41 <- four863mrrnrsxrkone
#
# 71 <- sevenntgvnrrqfvxh2ttnkgffour8fiveone
#
# 49 <- 49fbsfb
#
# 33 <- 3rbmlsksg
#
# 62 <- ztgszqjjsrtmgqx6572
#
# 37 <- 3bqnfxkdbonesixseven
#
# 37 <- mfgx32ftpbhgngm7
#
# 62 <- fzrpfhbfvj6dbxbtfs7twofksfbshrzkdeightwoqg
#
# 22 <- 2xcftwo
#
# 48 <- cshmmltsml4fiveeightdn
#
# 81 <- eightthsix1
#
# 23 <- two1gvfxcqnrfnbeightthreexznhbmmk
#
# 37 <- 3917sevenvxqxntcgxskh
#
# 93 <- ksctcnfxdsk96drlbjkthreesfqlvnpvfbcbmg
#
# 86 <- 8nvrmzfs46
#
# 51 <- 5dbgltmgg1xvtqfkdxsrxzltwo1pgqlqndlc
#
# 85 <- eight7four6rpbtmjzj5
#
# 47 <- 41seven
#
# 96 <- gpmfhninexxgqr6
#
# 16 <- 15sixdrhxzcmqf
#
# 85 <- 8fivettgmcslxptwofivelckzvfkl
#
# 62 <- 67ninetjngsrvcpxb8eighteightwofh
#
# 48 <- 4nine7oneighthm
#
# 27 <- njtwonefvhjplkjgvsevenbjg77
#
# 89 <- eighthrspkszngkpdtzdpcsmjnvlnhcm9pqmpkxqmbtmbv
#
# 92 <- ninehthhgbfsrrbpn2qpcflhgdvh9twotpzkvzmmsj
#
# 64 <- 6fourzpjthmkrkvqkvvp
#
# 66 <- vnrnkfp6
#
# 46 <- pfouronefour6
#
# 87 <- 87fourmznhvmt7
#
# 19 <- nxbssjc1sevenvrcjlczct6ninekclbffs
#
# 89 <- eightrpzsdggsixthree9dhrnqtjcbxthree9
#
# 88 <- pkcmnktzvdjtbbkvxhxpsfp8
#
# 11 <- sffd124fkqsq1bd
#
# 92 <- txzsmrzlcnnine72kgfkcf
#
# 52 <- dbfbdskfdn5nine2sdr
#
# 87 <- eightseven47six57
#
# 26 <- 2eight634sixmlrkhrbslf
#
# 81 <- hpeightwopgrqmblthree1fmfnvd
#
# 22 <- 2jbbf
#
# 74 <- vdsbvmjseven4eight195vdkfc4
#
# 59 <- five3xjzlrmxvqznine
#
# 95 <- nine4vqxmzqxcvfhlm45
#
# 21 <- rtwo1
#
# 68 <- six8jddkprxvbh98hd
#
# 54 <- five5sevenfourfour4
#
# 75 <- seventhree4lnxcvdprp66hsjfive
#
# 94 <- ninevrxxhgvkghmcs8gsvplvsfour
#
# 65 <- 6bkeight3fhkfqvvsbcsixljfive
#
# 62 <- 6sixktwo
#
# 72 <- lmscbrnlzmbqpl75ptwo64eightwoxcm
#
# 24 <- 2sixfivetwoeightdpskxjtlrfive4
#
# 85 <- 87gfmklvnzfz4594qlksr5
#
# 55 <- five3one65
#
# 77 <- vxrnhpvrrdd7nqdjfqnhfglfive7qqtzhcrk
#
# 76 <- 7sixthree441pf16
#
# 11 <- 11hrfdvdkf
#
# 75 <- vst7three2vtwojrkdkjltgdt5
#
# 25 <- vqmtwo5
#
# 82 <- nffpcvfpjleightfiveeightknmjfive2
#
# 18 <- ddfhzdndxvhcgjrcmqq158
#
# 84 <- kkeightwo14
#
# 82 <- 8onetwo
#
# 79 <- sevenrslxphqpcpdnxhpzqdf1twoone9
#
# 46 <- four8onelgqhkmxktf5six
#
# 81 <- 8ckshssfour73twoone
#
# 35 <- threethree8onefourkkhvfive4five
#
# 69 <- 64xpzhxtsixseven59
#
# 28 <- two8srjslxss
#
# 67 <- sixsixninecpgjkfhzdqdjlc48seven
#
# 13 <- lpjgghdtgk1sevenzpkmxzqxfourthreethree
#
# 26 <- cvznpxfhj2jnlgmnbkdsix
#
# 94 <- ninetwo1fournjqvsb
#
# 33 <- sxhl3kc
#
# 71 <- mtllnjrbscfkdhseveneightgjr4one
#
# 94 <- qnineeighttwovjsnvs7five4svdmjt
#
# 73 <- bcplhrpvmkxkjxlzl7zkbpdnoneninethreej
#
# 19 <- 1mbmfktgtwonine
#
# 91 <- 9threefkptqhhnine2six1fgxnvvfvplv
#
# 83 <- 8onefourtwoxl42shxq3
#
# 33 <- 38rlbhvlpeightfivelbcm3jfd
#
# 91 <- 97one1threexjfsljjz41
#
# 14 <- kqmkvmh1three9three74
#
# 32 <- 3fivenineeightwod
#
# 66 <- 6sixkgnqqb6
#
# 73 <- sevenjdn8csthpjxgnd83
#
# 19 <- qhssrppqxlone649
#
# 35 <- 3gjpsncshmnhkdpzskmmfst3sixfive5
#
# 56 <- fivejprgsxddzgcnrn6cpnxnj
#
# 49 <- 4three3ninedqknine
#
# 66 <- 61xfrcfseven6
#
# 54 <- sfpqbxbdrhqkndfdpldvfive7gxmnthreetwofour
#
# 23 <- lbvrzv2onec2six8three
#
# 98 <- ninenine2grvzhgtgfourthree98
#
# 16 <- 1579416
#
# 56 <- 5fzcbbxzfjjtwo6k
#
# 63 <- xmxbtqvnxf665lplnhlgjlkzhkkbknjcxqvkpsp3
#
# 55 <- fivefive26fivefour5
#
# 57 <- 5dbxqcbbkjonehseven
#
# 11 <- 1k
#
# 86 <- 8sixqmone9zthx6
#
# 16 <- ldsmxpbkkx1rppscjfour3six
#
# 58 <- fivethreethreekxzgqmrz8
#
# 67 <- lxklrjjmqsix5snb7
#
# 36 <- threethreetwothree6
#
# 86 <- 8three6
#
# 93 <- fnine7jmmseven3
#
# 82 <- rfhlkhhlx8sjqgclvlsctwo
#
# 58 <- vrzpdfjs5fxldpnhvhmmxhleight
#
# 99 <- 9tmqznszjgrnlhnpxbc
#
# 33 <- 3sxfscfseventhree
#
# 52 <- 565vs2
#
# 46 <- four86six6
#
# 16 <- 16
#
# 44 <- 4vbcrh
#
# 62 <- 62jrjfrdcldbvjzhp
#
# 16 <- onecsqpbrxpmqtrbbtxnrhkdlthree3s1six
#
# 28 <- two798tqsjv
#
# 28 <- znktgzzmtwo28
#
# 81 <- 8hllzrjqhvfone
#
# 24 <- tgnlbtc2ninejmcsixfour
#
# 55 <- fivek1five
#
# 23 <- rklpvqfvtwo3
#
# 55 <- lgdgchcpcl55hfdmdj
#
# 19 <- onesix7onefive9
#
# 37 <- jrnthree46seven
#
# 88 <- qqptcnrxlllvccssrkkmkxnz8
#
# 43 <- cmfour8threelthree
#
# 38 <- xfgqc36oneightvlx
#
# 21 <- xrvrchbdhftgpn22fgmnhbrscfqrqpgzjmgfive1
#
# 22 <- stwotwofourfourthree2
#
# 86 <- eightjcfqthcvcgpxxl6j
#
# 89 <- cjvfdgmplfeight9
#
# 52 <- 591eightwoc
#
# 99 <- jftninejfb11one1zqpnine
#
# 34 <- threeqndgjdfive4fourhgcsbptb
#
# 76 <- 7pmxvqdhbhf8six
#
# 65 <- 67zhx64tlnjkvhvv5cblxd
#
# 21 <- 29zqfive3jkzmbj1
#
# 17 <- smvlmnph1seven
#
# 64 <- 61four
#
# 18 <- zjmgnbkoneczgsftnhtvfbtjvbjzpspcffrdkv8
#
# 34 <- threesix4
#
# 88 <- fhqm8
#
# 91 <- ninefour1
#
# 28 <- two422dqjqhvhbqkdqf4sixoneightgrd
#
# 38 <- llnrdbhthree778dqzrcplfoureight
#
# 82 <- eightjblmbgqhrj2onenineszr2two
#
# 81 <- 8cxbxqssfkzpponeppcqsx
#
# 71 <- seventzlsxrskxqm8threecrclkpqjpmeight1
#
# 91 <- nine1twonem
#
# 69 <- 6threeckmkktkvxjteight559ldn
#
# 29 <- 2zxhldmvpqdcddsxpnnvrvxmc99
#
# 47 <- fourone4dzftfnccnvzjdrg49seven
#
# 74 <- 7eight44
#
# 83 <- xmjqm8two47rpjfninethree
#
# 74 <- 7zhmjjhtrqjcmfprhsix5twobfive4
#
# 88 <- rccsqlt8
#
# 73 <- seven6three
#
# 35 <- lrbp3five19zxb45
#
# 89 <- 8jlbtllzbtdgzbcfln929
#
# 82 <- kdeightlfk9two2fhgshhbzhf
#
# 47 <- dvxllmfourpzfpvch7
#
# 48 <- four28
#
# 38 <- 3threefour4hxmfbmjdheight
#
# 69 <- 6twosphthbbqcltcgxm5ssvqndphrnine
#
# 46 <- 438rrxntninetwophsix
#
# 87 <- eight3eightnine1sevenxsvfr
#
# 42 <- 4643kntqsvgqqtwo
#
# 22 <- two8two
#
# 72 <- 7gbxkjonetncmeight52
#
# 57 <- kg517
#
# 13 <- onetwo933
#
# 28 <- fbdmpjrjsscsfvfntwofive8tzbrbjsj
#
# 71 <- 7eightfive9nineninednsfhzvtonepccctxssbc
#
# 98 <- 93twofour2eight
#
# 75 <- 7bvzknzdmkjvrxkfngfnsd4foureight5
#
# 14 <- onescsxpcfivelmqvfqxmc99vbshtgzjkjfour
#
# 11 <- 1hvdnine1
#
# 53 <- 542zhgcmvzcj3threefrvlcc
#
# 93 <- sxfc95seven3
#
# 41 <- nczqknxn4four7xj81r
#
# 85 <- 8threefive
#
# 74 <- 7zvhlf4
#
# 94 <- drbxjhqp9gfgxxtkl4
#
# 54 <- five2twotklsixfour
#
# 99 <- 9four9
#
# 29 <- 2jkeightthreekbqbkffpsztwonine
#
# 32 <- 3vtffqfkfh9onenine4rqxm7two
#
# 41 <- 4hlxllh7nrlxcpnrrcfivebkfkjdfjbksnine1
#
# 34 <- drgsb3four
#
# 48 <- fourhscfkzkjfcdlsjgjrbmlvvcfgcmxtsixjlhfrfmk8
#
# 51 <- ncrkhfive1eight1
#
# 88 <- 8fz3zkhgleight9tqsgnbfoureight
#
# 52 <- 5six26twoone3two
#
# 51 <- ptksmjfkl5twothree4fpshnrcfrmqxeight1
#
# 45 <- jfkccclrrr49four6eighttwo5
#
# 36 <- threefourgj7eight6
#
# 75 <- 73slt1one5
#
# 61 <- six1zrlfk
#
# 57 <- 5six17
#
# 62 <- qrsix7sixonexmclfz2
#
# 33 <- 3fivethreebplrfgklj
#
# 91 <- xz9sixhlt4eightone
#
# 67 <- gkknnbzkt6ffourvrjbfkqz8threesevenn
#
# 29 <- 2onenine9
#
# 14 <- czsgh1five4qtxmtfksln
#
# 84 <- eight6fourhpppr
#
# 86 <- lpshxfqsddeightqrfgrdn1five6bnr
#
# 57 <- 5lmmlszndzfoureightqdbhlt7
#
# 95 <- 9eight5
#
# 85 <- 8sixrpctqfgf9dm95znhx
#
# 18 <- 1sixsix6qpmqmtwolh8
#
# 62 <- six4threenine2four982
#
# 89 <- 8jbthree59nine
#
# 55 <- q5
#
# 91 <- 9twosixone9fivehdsvpkttbkcjdbkone
#
# 64 <- sixsix4cldngone3four
#
# 99 <- 9mvsggrgone9gjhfzdmvqbnqzlxgpckg
#
# 88 <- gmtqnkdlfv8
#
# 84 <- 8seven7rxtzksl74four
#
# 24 <- bmrtbjzqhbgzcjtwo74fourfourlvj
#
# 21 <- twoone4five3twoljrznhdcggone
#
# 47 <- 42nine1eightseven
#
# 46 <- 45fiveoneseven6
#
# 45 <- mxfoursixone8coned5
#
# 67 <- sntmhcsix633seven
#
# 84 <- eighttwolrcrl5four
#
# 22 <- p22
#
# 11 <- 1vspmvx
#
# 92 <- cpcsx9xgqlmblhshvnsix2hnczvdrrg
#
# 44 <- grgtvsqdtslml4tlqrh
#
# 33 <- hshgmv3
#
# 51 <- fivethree63m3one
#
# 93 <- 95threecdfhqtmqb
#
# 17 <- xjvd14dnfrjthqxvvq1xmqfhv7
#
# 86 <- eightnzx48nkqhfssix
#
# 86 <- 8nzvck4hpfxbstf6fivesix
#
# 44 <- 4drxbsxgtskqtlnhgrrrz
#
# 68 <- 6foureightonezbpdbqflp5one88
#
# 29 <- twofivefbhfourone4cpnrc79
#
# 57 <- 5trhksixfivesix2k7
#
# 23 <- 25three
#
# 19 <- 1phc9zhhn
#
# 58 <- five8ptkczvqk87gkr8
#
# 64 <- six61eightfourjjzrktr
#
# 43 <- 4gxrqrrvkshnpgnrjg2threekpcrfn
#
# 71 <- 7bclvsb1glbpss
#
# 28 <- 2eighthdbvxpz
#
# 49 <- 439
#
# 32 <- 3drtsf2two
#
# 97 <- ninenine8hqqmfvddgspzdsnine7
#
# 23 <- xzrjqdlrp2threedrhjztbsvg4mmqvchlhlp3
#
# 91 <- 99threesixzpgxnseven5one
#
# 22 <- 2hvst
#
# 21 <- twohvrvp164one
#
# 18 <- 1nine9seven1eight8
#
# 95 <- dfkdzprs95
#
# 34 <- zthree925fourf
#
# 13 <- kssmqhkonetwozcjgvjgxzr3gfdcvgm
#
# 66 <- bbsqsix6
#
# 13 <- onefour9seven73
#
# 11 <- onesevenx1ncpgtczseightssevenone
#
# 43 <- 419d43dzjlvn
#
# 91 <- ninefourb6threezgqvmzklghgsj1
#
# 73 <- 7crdxpfkcmtqvbvkk3
#
# 82 <- 8rvp2p
#
# 85 <- gnvrlsfjxtfssqz8two6dcfive
#
# 28 <- jgtwoneoneseven7oneoneeight
#
# 43 <- dfsccdclmffourpsqggngjzn3
#
# 22 <- 22brtxbtkkdfmkbmv
#
# 67 <- sixxlpxqdtwo7
#
# 65 <- six8mrvhptlfbmczlnfqrgbvz5d
#
# 88 <- 84fiveeightsix8
#
# 92 <- nine5rzqxp99gmklplmxtveightwombf
#
# 77 <- seventhree7
#
# 21 <- mfklcxxbhpqsdt2one1
#
# 22 <- two7seven2
#
# 65 <- 63sevenpmdzdrkzjkjzgnnseightjztlvzqhx55
#
# 83 <- 8twosmrgbzzgmjbnthree
#
# 24 <- twosksrj4mk
#
# 18 <- onethreeseven4eight
#
# 23 <- 2kjldqzszg7twolfivethree
#
# 35 <- 3qdnbnzglheightjtnlqqqt5
#
# 64 <- 6l4vddmkphgmb3vcbsbgclkzhmmtmfour
#
# 68 <- sixvtzmppfssl35eightqc
#
# 65 <- six924lt5
#
# 57 <- 5sixnmmeight7
#
# 93 <- mkggvlrdhkjxcr9jcs2fhsptxhj3
#
# 91 <- nineggh1
#
# 33 <- qzzckckm3
#
# 34 <- hxgjhxthreetwo3x4
#
# 72 <- 7qonejntfsvpcftwogxkvpvbj
#
# 23 <- 2twoqlg3
#
# 16 <- 1sixhvsclvhshbr
#
# 78 <- seven8tffqvgs
#
# 28 <- twobktthxfqqthree38
#
# 37 <- 397
#
# 97 <- lpm9six31seven
#
# 75 <- 75nrrfxrj
#
# 84 <- 8sixfour
#
# 22 <- ccfbzbjjqlgkbqnxhgd2
#
# 71 <- 7eighttbrtddvbvrtmxjeight5nine1
#
# 62 <- sixfourvbjv5six61two
#
# 67 <- sixff4dskpsqsrcd7
#
# 38 <- three5five8
#
# 86 <- 8sixthreethree6
#
# 13 <- oneeight7cdjxfmfjbpbjlsevenjgthreexh
#
# 96 <- ninetwo4xdxmxpmd86
#
# 82 <- eight312
#
# 87 <- pmvgbvn8seven
#
# 31 <- djrftlbzvfxjjgrh37bmfkone
#
# 56 <- ksf53onefourfive6
#
# 79 <- 7vzqrmklveightnine
#
# 29 <- two55eight69
#
# 35 <- kbjprbkcgpskbnthree6gznqk5fkttt
#
# 27 <- 22three37bvmsmjmx
#
# 16 <- zpchdzmbjhzl1five26threesix
#
# 25 <- 2onetdppvzcbzfive29four35
#
# 69 <- 66one9clqlkbqpfdqkkxv
#
# 54 <- lql5four
#
# 27 <- two41sevenseventhreeone1seven
#
# 56 <- fiverbkxdczfive6smlnbgn6sevensix
#
# 84 <- lpveightwoeight9two4frfz54
#
# 21 <- twohfkvxqrninesix1
#
# 66 <- 6twosix
#
# 97 <- 9ninefive47
#
# 67 <- sixsixrjznqb33sevenhkl
#
# 18 <- one5nineeight48zqkhjgqlcq
#
# 43 <- foureight4seven83
#
# 16 <- zzoneightvcnhxlmgjp4ctclzzztwo46six
#
# 21 <- 2gljzksrvdr21ms
#
# 85 <- eight75twofive
#
# 36 <- threexdsbjrf6
#
# 36 <- lhvrfb3925six
#
# 13 <- fgrlrvpnctkdblxvzone2tsxst43
#
# 58 <- zpnbvs5foursevensevenjleight
#
# 57 <- five89seven4seven
#
# 54 <- 5rnntxqsngssixonefb3fourdglmstvmft
#
# 33 <- tmvldx3eight163
#
# 66 <- hmnvbpr6516
#
# 33 <- 3jfqshjf
#
# 91 <- 9vgpgcflbbonejhmlncrrjvxdcshdflktr
#
# 76 <- vgjmhqnvghc718sevencfdzknkhonesix
#
# 33 <- dlzrjfklp3chqxjdpdrv
#
# 87 <- eightseven4tcbdhrgssmpvxsxszxrmpzrt7
#
# 52 <- five416sixp2
#
# 24 <- 2threefourj
#
# 14 <- hmzoneightmvrksbxbjkvpslkv1tlxxkzsgdseven86four
#
# 85 <- pzleightwo774five5
#
# 29 <- dvsmtwokrzscgnvztznqh9
#
# 62 <- 6chqttwo
#
# 65 <- 67sn3dfdeight55
#
# 48 <- 4oneightqd
#
# 61 <- jhlhcjnd6sixqptqlmrskfive1
#
# 93 <- 9mfxbvb138zxngghqs43
#
# 28 <- 2srctwohfplclone928j
#
# 72 <- 7eightsdsxsskkd8five82
#
# 19 <- gccnsvpnfg1195nine
#
# 87 <- 8584threethreeskzkfpdhz7
#
# 57 <- prhhdpfivenine5fsskx5eight7
#
# 95 <- 9nzhbn7mvczcqcfive7tslfive
#
# 72 <- vqxseven5seven4332
#
# 95 <- 95sevenninefive
#
# 84 <- eightzdnddmlrpbxnvxglqnqnr334hpjrl
#
# 13 <- one6three
#
# 15 <- 13dhjftxnp5k
#
# 97 <- 92threeone3seven
#
# 28 <- ncsfdmmft2eightmlfxxdbv
#
# 49 <- four3ninethzh
#
# 35 <- 31five9ksssbdqzlfive
#
# 22 <- twokghhrljdc72
#
# 27 <- two6fourdktfpddftwoseven
#
# 33 <- zgr3bdfqvnkdvpcntkrcfnhpnpdrtkzpthree
#
# 99 <- 9rnpxdtkbhjbjnf
#
# 13 <- 1247lqdnsgnp3xtdxnbxkrthfhsrm
#
# 79 <- sevendcdbr38ninebljxshxdzqcknvld
#
# 68 <- six3gpngxvdqlnrf9gjqjvzeight
#
# 27 <- twogfxctgnb4sixqzdmhc2sevenbq
#
# 75 <- sevenpjmrj2skcc5
#
# 86 <- eightsix9threemxtx13zczqvtvsix
#
# 19 <- 1tmgrhxzfql9lbpgscnmlcghptbtmpfgct
#
# 27 <- 2foursdhmtqmfjlf77
#
# 23 <- bmgttpr2eight177six9three
#
# 11 <- 1nmbnkszc
#
# 39 <- three14six1lnlfpfmfhm9
#
# 89 <- eight4four6five46nine
#
# 25 <- 26sevengdnoneeightfive
#
# 11 <- vhz1fivejzjqnfgrpfbgfz11nlx
#
# 49 <- 4jnkzktpninejc
#
# 93 <- ninefourone1five2four3
#
# 62 <- cljtfplrgbv6fsrlfxqmxhtwo75two
#
# 41 <- 41htzjlzsdbg
#
# 97 <- hfnvdnninezhhbsmxfour3ninesevenhdnflzlt
#
# 87 <- 8vlshckcch57
#
# 28 <- 28tsbvgmzd
#
# 57 <- qccgcsqb5trsvmmdtninehbgsxqjftrvsix7
#
# 31 <- 3eightkfqlsone
#
# 11 <- fgoneightsix4eighteight4one
#
# 85 <- 8csdgpcbfjbmsixmjztbrqdj5
#
# 92 <- 9two152
#
# 11 <- onevseven1
#
# 56 <- vfsjtpzttxdrfive6
#
# 69 <- 69mdbtdnqgxjmzt
#
# 35 <- threemgzspvnvsjone7eightjxssg5
#
# 37 <- threelfslcjhhgmfftmftfzsix3qs57
#
# 17 <- onejhskmbxcqpkxjxh4threeeightseven
#
# 98 <- hhvgnineeight8xrtvmqjnkccdptpvqxlrdkkgljmbnzx
#
# 15 <- onezvj2threej5dlnrcbhfxlkkmkpx
#
# 92 <- ninepmgbdcvpds3onefive2
#
# 92 <- 9tblnmmeight1xdmtwo
#
# 94 <- cnczmrhjmmcsccnine54
#
# 25 <- 2fourggjjrxckgvsevencpkgqzzfnptwofivefive
#
# 69 <- 61threexnrhqbhxb9
#
# 74 <- seven14
#
# 37 <- 32seven
#
# 42 <- 4cqtssgd3vdxbnllfb2
#
# 89 <- smbqxbxgmeightthreeonedsfxfronec2nine
#
# 32 <- 3145fvqz2
#
# 99 <- bgdgbptnr9dqmvvckb
#
# 23 <- tpt2ndklfgxtthree
#
# 45 <- four16vztcgtwo5xkjmp5
#
# 51 <- 59onelp
#
# 28 <- ztwone9cnvbtpglsq78
#
# 49 <- 4rmmhxpqsknxhgqmlh9tfzfngqsnbqdmsgtcjsbntr
#
# 47 <- 4x6lcmrxhhkcscxgxtgpjz33seven
#
# 88 <- cnzlsqbvk8sbbzphzkhmeightfive58
#
# 27 <- twofour7
#
# 85 <- jcsgmrgeightcpzbb8135
#
# 48 <- 4grxpsix7hgrrhtjvgq68zzbvsn
#
# 66 <- qc6
#
# 98 <- sgxdninevmmzqdkqmjxpksixfckbjjkgqtwoseven8
#
# 69 <- 6lhfcjc9
#
# 11 <- zkpkjn18six51
#
# 87 <- xtnhzzxceight6seventhree27
#
# 25 <- qttwone3seven5
#
# 39 <- threeone8ksgt9
#
# 88 <- 8fqkddzb
#
# 99 <- nine3sixbprlvxpniner
#
# 33 <- dmbvmrthreefcrqvmhp54neightcz3
#
# 28 <- twosl6fdtwokrqrqtwo6eight
#
# 83 <- 8dkrshdpj8threer
#
# 27 <- 27snqfjdg
#
# 99 <- nine7mdsonenine
#
# 39 <- threefive2twotktc9
#
# 17 <- 1twoninesjgqjxphhnineeightthree7
#
# 22 <- xxlcmbnctsszkjdhfzqbdr2szvkmscnrg
#
# 96 <- tcmsnine6ct
#
# 22 <- 2tqmkfmc
#
# 71 <- sevenpmceighteight1
#
# 39 <- hnnthreefourknjznt5nine
#
# 59 <- 5fhjvttdmzdpkjdsgnpqxlxfninepgrsns
#
# 64 <- psxzzdkspgmgnnhkzt6fsdmfour
#
# 11 <- 1lkb
#
# 73 <- seventwo2dglxkrlvgthree
#
# 72 <- seven27kzhnknqltvkbxrtvtwo
#
# 75 <- 7frmrdctninefive
#
# 69 <- 61twoninebbsbqsbhtxmxkffspd
#
# 38 <- 3nlzgzlntrk965nine8ljpj
#
# 32 <- 3pfxjjvcg42lzlkzfs
#
# 74 <- 7pkztnine54bq
#
# 63 <- sixxbxvgsknjxsix4nine3
#
# 49 <- fourvbch2cdrsrxzh9
#
# 14 <- one1f4mtvslfczm
#
# 46 <- 456bkzhmxlmhfmkgxrmkbmvhhpmsfk8six
#
# 18 <- one9rmbvtdp5oneeightfive8
#
# 64 <- 67zh4
#
# 89 <- 83hdqrsxfc2twoninekksg
#
# 13 <- 1gzmqcrtksixseven81three
#
# 22 <- two6threefour2
#
# 94 <- nine4rcmbhmhsttgqzfjdm
#
# 63 <- jg63
#
# 21 <- twofour3one1
#
# 59 <- 5eight1eightqdmgtszxvx26nine
#
# 47 <- 482three9seven
#
# 14 <- cxdjmjsk1mgqsqkkbq97fourqflf
#
# 66 <- bvfplgzj69pqfcpglsix6
#
# 34 <- v3458fourcpqkn
#
# 79 <- seven769sevenfive9
#
# 13 <- dztdmlkjgonejjpxrsevennineninepkc3
#
# 43 <- 4ninehvgninethree
#
# 66 <- tnvgjhzr6
#
# 79 <- sevenfour5nineshrsknbbxxsgztrl
#
# 43 <- four4flpgsixshxxtmnvxfivensznine3
#
# 78 <- 73cfxzzsfourzqghjqvkbf7six8qgcd
#
# 13 <- fgqk133t
#
# 11 <- vjbzpkvsxkoneoneeighteightfive1zrvgqbf
#
# 96 <- 9six6ntrmhtkgrj
#
# 45 <- fournrrmxldk24mxhsevenfive
#
# 89 <- 8fiveninenine25ninenine
#
# 76 <- seven1xb3vbzbqkjdvseightfive6qs
#
# 57 <- five8dgqkhldbsfthree7
#
# 68 <- six11three5zeight
#
# 55 <- hgmqhchrdfivevmftjcgtl5
#
# 11 <- oneonesix2bzfsqvkmjzbdq1
#
# 49 <- fourx5threethree3mxhgtnine
#
# 89 <- hzeightwozfcpkjvfour3three9b
#
# 17 <- 1oneseven
#
# 47 <- hmdtcxld4fdgfgdbjlsevenzrkmnftsevenvsqc
#
# 76 <- sevengzpnkfn1sevenjcbfxbg8six
#
# 25 <- 2sqjnbtskft5
#
# 94 <- fknxnxg9944hvtxj
#
# 91 <- nine3951
#
# 98 <- 94sixqslqtxleight
#
# 13 <- 1zpbxc3
#
# 66 <- sixddscq1zxsvgbjnqjj6zknkfczj6fxcqmf
#
# 32 <- threetfvhftlzjn72sevenljtwobhgvvsttg
#
# 13 <- doneighttwo3vm
#
# 22 <- llhzdtwovbxr2
#
# 18 <- onemjkvtbsix39eight88
#
# 46 <- lhzgpqmhm4ptmcxhseven4eightcrvnqzplrnb6
#
# 31 <- 3tqljjnx47sixsixmxqbflxjp1
#
# 35 <- tkvdxbbsdpkdjl3gtnmjdxhrj5
#
# 98 <- qgnnghvnkppvvnine8
#
# 88 <- 89sixeighthmhsvbsg
#
# 67 <- 67hqvxtmq
#
# 57 <- fiveeighteight7cfmdmfhdld
#
# 87 <- nnsxvrgpeightjvcfj3fjeight27
#
# 81 <- 8ninefourfourcjrbxone
#
# 12 <- 1bx482
#
# 17 <- pponeight1seventllldzgdvgcdmr
#
# 24 <- tworrjfkmntbvkpseven4jnrllr4
#
# 99 <- ninesixsix9
#
# 23 <- csv2ninesixtwo3
#
# 93 <- 9vzrvg9twokbjcnvcghthreeskfpgssbdxq
#
# 42 <- foureight6133rszlz2zvxdx
#
# 66 <- 6jfklqcdrgm
#
# 35 <- 3sixhds1kgfvzknhthreefive
#
# 77 <- fbgnjqhnghssthzshktxll7rqnhjqjb
#
# 52 <- 5xjkchhffgz2
#
# 36 <- threexjkeight86
#
# 33 <- three8eightztthtfvzdxthreethree
#
# 85 <- gdxjvzlktltseight5
#
# 24 <- twomxfqrxqkrjhs4
#
# 54 <- fiveeightnine1ninekhrjbmqhmpjqxtqsjpzbbvnbbzmfour
#
# 13 <- nxnrqtsplonefive6zrthree
#
# 82 <- 8fivejmr1lzbdmvdpdrhvsthpvone2
#
# 23 <- 2sdfs1threejjxvjxp
#
# 87 <- jhkeightskq7
#
# 14 <- 1eightfive4
#
# 58 <- fivefqpmq7twoeightkggxgvrbmbhjdzrmn
#
# 51 <- 5twozrcnf9fourtmxjtkmfiveone
#
# 54 <- hghfivedpgntxbpndqm4
#
# 28 <- twodzbplxm9xlgvnmfvxh7oneightzvm
#
# 73 <- 77eightsixxlvkzfive3
#
# 77 <- qrgz7
#
# 81 <- eightkdcvchgfourqtrtxtnzeighteightseven1
#
# 66 <- 69onefivetwoone6
#
# 21 <- 2onetwothree81qvsmzxpvmpbgsd
#
# 23 <- 263383seven3rrmskzfgcj
#
# 33 <- threeeightthreesixnzgkggflxfour3
#
# 68 <- ggk6two2sixeight
#
# 86 <- eighteightseven8nine9six
#
# 39 <- pzthreenine2nine
#
# 58 <- 5threefivecpxfjoneightjcn
#
# 17 <- mdmhone4ninesix92two7
#
# 21 <- nm2twoonerqvckjtxjlzvldq
#
# 63 <- 6fourzxgncsixninenine4ninethree
#
# 88 <- xxflpfeight5nine13qsgrqvsz8
#
# 13 <- 1threeseven4mvfzm653
#
# 87 <- eight23three7dkgdxkrk
#
# 93 <- 9lqvhv115threezmcnbplgfzjlqmgrpjn
#
# 25 <- 2pgphcxbglfive5vtldzlrrnx
#
# 23 <- dshlq2zcqhzssbdseven5twothree
#
# 85 <- eightpvqcqnsprhtvlh5
#
# 73 <- 789sixtwo3
#
# 86 <- eighttmzkfzksd39sevensix8six
#
# 52 <- bkk5two
#
# 78 <- gkgqxksdpn78
#
# 57 <- 577gnmbvzf7
#
# 61 <- rcfl6foureight4mszdbmkl8one
#
# 17 <- 17n
#
# 82 <- fvnkgxqlpflmmnf8eightsix3twokgj
#
# 82 <- lh84twosvptcklvt
#
# 61 <- 62one
#
# 89 <- lmlbfcxpdqlmeight94nineknk
#
# 34 <- threenine5three4qqhtfkg
#
# 39 <- 3nine8threetwoc5ninecxcc
#
# 11 <- sgxrhdonefcpone1tsb
#
# 19 <- oneqjkppzkpmzcgqv7nine
#
# 19 <- lfngqdlhone4rhfsrgdldl5mrpvzr9
#
# 58 <- vvvhfbz52eighttbbr
#
# 93 <- 9threethree
#
# 96 <- cnntzjvnplnineeightzdmtsx6
#
# 43 <- 4ninefourdndsvnbthree
#
# 38 <- 3zbt3nine28
#
# 13 <- 1seventhreedfggtfvvsngszlsix3
#
# 64 <- six13nine14
#
# 91 <- 9gjzdmdzssixone
#
# 92 <- nnxbmrdmjdhrjnhktlprtbvknninefive3662
#
# 69 <- 6rrmxmfm479tcxmvk
#
# 98 <- ninedfchdzxbmlrjkckkjpqqxchz58
#
# 32 <- three22sixeightrbzmdlfztwo
#
# 74 <- jqljmhxgmfxkgsevenone77ffour
#
# 96 <- 9xbphsix
#
# 19 <- onetwo271sixninek
#
# 77 <- sevenbdxtwofivexscbkflmkncvh7
#
# 72 <- jxlqvscdjz7six62
#
# 65 <- six4five
#
# 88 <- eightsevensixone7eight
#
# 59 <- five4five9
#
# 93 <- btsjninegdrcbxdrgmmg23q
#
# 67 <- 67mqtphlkhtp
#
# 37 <- 3drdmqx77
#
# 89 <- 8twoninenine
#
# 83 <- eightfcng16kzgtfzbdfxbltn113
#
# 68 <- fc68
#
# 38 <- 3rkqrhlskj8one8
#
# 89 <- eightqtkls21five99
#
# 41 <- 41clcg5qmfkdkq6snghpone
#
# 82 <- pdmnvqhg8vjrvlld9ninexcglqpgm62
#
# 79 <- 7one4two2ninencplhmrztsqjgt
#
# 66 <- 6cvdc
#
# 28 <- 2sixone76eighthqrlmfxzk
#
# 68 <- six512nrsstwoeight
#
# 22 <- 2fourfourqlctwo
#
# 68 <- sixb23seven3eightcbmvk
#
# 32 <- jxthree1bvtwombbmcdbsbf
#
# 87 <- eightzdqnjbjzd9sevenflcqqflk
#
# 41 <- four88sixtwotnmzrltlnineoneddrsxk
#
# 95 <- 9six5
#
# 56 <- 5ninegfhvsqblftwogmmfgddncqfmqjtqvbc6
#
# 98 <- 9svv5jlfbrvpntgpqkkg68
#
# 44 <- khglrpxfqqfour4
#
# 46 <- qkfour1sixfnpzxkdzr
#
# 22 <- 22onefivemhsxvhllnzr2
#
# 11 <- 1onehpdqbrklhg
#
# 62 <- bs6sjsndrz2
#
# 89 <- 8five9
#
# 95 <- ninetwo3five5xmpkzrnqzq5
#
# 22 <- 2797two2
#
# 94 <- 91tdmpxtrkfourq7fourcvtbmsk
#
# 42 <- four82
#
# 32 <- three3sjgxtp86eightwof
#
# 63 <- sszzthsixvrdbglczld3
#
# 45 <- four1fourfour5sqknhn
#
# 84 <- vlhzqfbht8px7kznvtffourq
#
# 33 <- jshqhczgr3
#
# 41 <- 4two1fvvxdfms
#
# 83 <- seight3fghflv
#
# 37 <- tgqdzsdzdthree787
#
# 48 <- 45nrdlxtqggcseveneight
#
# 83 <- 87tkbsmfvhl5five3zqx
#
# 66 <- 6rmpdxvrlszpjtqmhcd
#
# 42 <- fourtwothree49346eightwohq
#
# 99 <- 9kkgdv
#
# 18 <- ndoneightsevenfive8
#
# 37 <- threeonecc63pvgxd7
#
# 28 <- ctwone8zbxbf
#
# 41 <- foursevenrpkshs75two8one
#
# 22 <- 2jsvxtrrkjxjzxmh
#
# 83 <- nkf8three
#
# 67 <- gzbplsixeight86lxpcrzxpbx7seven
#
# 55 <- 5pzpfs
#
# 65 <- six12ssffeightfourfivefive
#
# 11 <- one2four71
#
# 56 <- 5onebhrjgrrltbsix
#
# 94 <- hclv99two89nsfdfour4
#
# 89 <- 8qk8fbflndsix9
#
# 16 <- lmvcprone16
#
# 16 <- rknqlczt15thqlpvk4pgllfmsix16
#
# 72 <- seven8jgpq427sixtwo1eightwokb
#
# 95 <- nine8xgghnfive
#
# 94 <- nineeight7ninefourrtbtd
#
# 35 <- threetwothbdmvtcrjgsm3fivehdqlxtxnkdstgs
#
# 49 <- 4sevenfourvrqfkhspbkqjcxjkjfniner
#
# 59 <- 5three69mzqfqrhrjdqhbpmscz
#
# 41 <- 478kj1
#
# 55 <- 5bhcrpjtvjsxpskmscxclpzxkzc8five
#
# 71 <- sevenhlxgzntwo4knxtcqscdone1
#
# 35 <- three5dmjg
#
# 37 <- ssxtz342sevenfivefive7
#
# 84 <- 84two9vsqlbh5fivefour
#
# 42 <- 4fiveninetwo
#
# 88 <- 8cqz
#
# 24 <- twoptxmcmnsbgrrndfdgtwo2ppglmzcfour
#
# 85 <- hdqfnlzrscveight5plplhvbg
#
# 75 <- sevenmgxjzjtwonine5
#
# 22 <- 2thfbhzjsdk
#
# 88 <- jmzsvtqjxmgstbqctdv8qc
#
# 82 <- gv8glpnsixninesxhzbmfqxkqfd8eightwonj
#
# 88 <- 88vsqztnhst
#
# 61 <- sixgf2sssrzvqlsm9one26twonedzq
#
# 41 <- 4five611one
#
# 66 <- sixdvbsctpqbqfive6
#
# 13 <- one3c
#
# 59 <- xcnkrcdxtfivefour3nine
#
# 73 <- 7srqvlkftzztpgrfive2threesix3gtzcnfdvs
#
# 37 <- 3hqsevenlzgbf
#
# 51 <- cggclvfppfive1dgnnqgzqzsdhdpbg
#
# 19 <- noneight9tktnzqnttwo9fivenine
#
# 25 <- 2nfourfourmmfltjvxzfivezfntcxfctqsdckcjl
#
# 61 <- htzvlsixsix8twoone
#
# 94 <- 91xnrqfdqsbrvf6sixtfour
#
# 24 <- hvtwonenzqnine9fourvtcdndzptfourx
#
# 64 <- sixfiverp8fourbnfgnlkqld
#
# 18 <- 1728
#
# 12 <- 18nineonejhbvdbm22jgrbsgf
#
# 25 <- 2rcpqxgsix8fivebscvblxzcmbztrlsx
#
# 92 <- 9threetwoeightxbsrxpjns4zkpztwo
#
# 65 <- six6sixfive
#
# 55 <- zpqjsckrcztv5
#
# 39 <- 3nvsixdnmfqplqtqpq9
#
# 14 <- onesixeightthree6nine74
#
# 66 <- 66sdh
#
# 27 <- 235lmnrgxztt2nctntsgfive57
#
# 59 <- fivegnzfnbfpvnl72fournine
#
# 39 <- 3jrfive9srqvsxxfz
#
# 42 <- vs4threeeighttwotrcpphdq
#
# 24 <- zlfcpfptwoninescshbtcdv58sixrkxfour
#
# 88 <- eightfour8
#
# 46 <- 4onesfkbnnfsevensix
#
# 42 <- fourhjsbvjgqhrvtdvmrzrtsixpglhrlcrrkr2
#
# 47 <- fourthreedczqpjskdsqnnhczhdc47
#
# 32 <- 3sevenfourtwobn
#
# 31 <- 3fivesix1
#
# 45 <- 4qbtlplbl25
#
# 66 <- 66grjtlgsbflfjbcdmdnnine6
#
# 18 <- 1rbszctwo7pkmvsixsevenoneightqc
#
# 21 <- snpvmbppvtwofiveeight1rnmfkrsfbhs
#
# 56 <- 5frcvcsixmlhfcv
#
# 22 <- 2nbd
#
# 53 <- 557sevengrvxddpdgfzsqsqx6three
#
# 51 <- five41lrlkdmhsbjq
#
# 88 <- eight3vzzgspkgqh4eighteightstthdqm
#
# 99 <- vqctjspmq9
#
# 42 <- four12clqrgts
#
# 48 <- 45two8zv
#
# 43 <- c4xklll3
#
# 45 <- four3hhfivedtj
#
# 63 <- six55two3
#
# 26 <- gxdttwo256
#
# 35 <- njthree45
#
# 74 <- 7threevl5174
#
# 47 <- bkvcbfournine6seven
#
# 48 <- four8jjg
#
# 72 <- 725rgkxrztbhjmsbxgvc2
#
# 98 <- ninetjqd48
#
# 99 <- xbpthl9x
#
# 17 <- 1sbf8seven
#
# 68 <- qfsbld6five7four18
#
# 91 <- 9kvbcnlctngbthqlbqlbfhttmf51
#
# 91 <- 98eight3vfcxzbsvfour4one
#
# 66 <- tlbpdxbglrcqppkcb6two6rbffxpzmnntpdr
#
# 57 <- fivevgnzjkjcfeight7twozvseven
#
# 81 <- vjmdjsrl8onetrnlgsclrfmpvkdblfourktwonet
#
# 99 <- tvvkszfvnineeightninetwo9
#
# 21 <- 2twollqsbnconescjjj
#
# 13 <- one23qz
#
# 98 <- nine2vbglpdpvfhrqp8eight
#
# 37 <- threeone7seven
#
# 13 <- vxxone8onetbgplp3
#
# 27 <- two1mlqrfour7
#
# 98 <- ninezdkbvkbonetmzxgszqxdnttkgsgqd7eight
#
# 49 <- vrfbzcfourfivenlgmvktszpthreepqkgfnjfc9rfmkxbv
#
# 95 <- ninezhsfngmbc5fivers
#
# 97 <- tzjxrncfnine1cglgmnmxhssevenbdmxfjtg
#
# 73 <- sevenseventwo5five9seventhreeflvgdbstfr
#
# 71 <- 7rggpvgkmone
#
# 18 <- 1veight
#
# 45 <- 41vk7two5
#
# 76 <- 7onetwoone6
#
# 29 <- kvm25nine
#
# 12 <- onekzcjprtxbncpqchpxpvtttvgmqfour3pxpcmfourtwo
#
# 55 <- chrrlnddfivefive5
#
# 84 <- ttvnlchqz8hrxhmgqrfour9rmkkdlr14
#
# 55 <- 5jcmdfnldlq
#
# 67 <- 6431khcknnine7
#
# 13 <- onegtmzngkqgfggfmhxshnzltdbkvmkjjvnfpkclhxntvngvlnqd3
#
# 44 <- q4fzzrpt
#
# 95 <- cllbnine5
#
# 66 <- six18ddmk22six
#
# 25 <- 2knsdjp2nphnonesevenfive
#
# 12 <- vqjkllm1threemfrnlvrmjzzsnhmxsxtwosgxjgjcqrtwo
#
# 65 <- six4onefhpxkpnqfivekbxhmxtbx
#
# 33 <- djsptzspn3eighthb9nthreelhpzd
#
# 23 <- twofdvrmxrcmfive27zdcssbvcsthree
#
# 53 <- 5eight5ptfgcnthree1zjvkk3l
#
# 32 <- 3one8two
#
# 42 <- bsdphtbdfour1twosevensevensix92
#
# 44 <- four7six4smppkbtwo4
#
# 82 <- 87dpqjbbtwo78662
#
# 12 <- 1ninefour8four32
#
# 23 <- 232spbt1jfzfourthree
#
# 37 <- 3cxxkqldtwosevenninetwomcdvls7
#
# 55 <- 5seven7pgnkdjgckfive
#
# 27 <- rvmfpjs2threespszkcvfklpdhtmbnseven2seventjrhx
#
# 85 <- eightfive3twonbxs5
#
# 32 <- 3frglvrm32
#
# 18 <- 19778gmtrsjkcrdqlptpjzg
#
# 16 <- zpvskbdztrone5eight3sixnmcpdshrgblddrht
#
# 78 <- 7seven2tdnblk782eight
#
# 12 <- mjjldone2cqmlmmzxbt
#
# 11 <- hfponeightoneplk66threezzklrkrmvronekhqsrnvm
#
# 46 <- lghjkgdssfour423sevensix
#
# 71 <- sevenfmqtwo1onecmrhrzhl
#
# 27 <- dmpf2fivethxhpss27jn
#
# 26 <- 2lnpfrdfour6x
#
# 12 <- onetpztmmfr2
#
# 61 <- 66qlzhrrlchcxznsjrfxqxkone
#
# 95 <- 9fivenlzrgm
#
# 24 <- mstbglvtxnzlnhjrltwo238bsfourczkvctl
#
# 68 <- zkz6dcdsfgssl8b
#
# 83 <- cgnqsdeighteightfourhnpkdvggdsixfour3
#
# 97 <- 96xschgpnlktsix4eight537
#
# 31 <- 31c
#
# 48 <- 4smrxzzpvqmrxhmltcmgq8zrxftd38
#
# 17 <- onemncsrqlklxdx9ngpbxhxpk7
#
# 22 <- gzr2sevenhjsczr5twoqsmhj
#
# 49 <- nkfh4eight9gzpkvvxjsqfjbt
#
# 29 <- two2nine
#
# 35 <- cxxqmzfnm3mbsmltpkpfour6fourfrjjcztt5
#
# 13 <- lxnqtpzldptcvnlcggonehndzmx7863
#
# 36 <- 3fmgl36lbcvrrczdfqdss
#
# 43 <- fourfour4xjxgmnctwothree
#
# 98 <- nineseveneightgrdvffkntwo948
#
# 48 <- fouronenine8
#
# 83 <- 8xfktsxszhn53
#
# 67 <- 6onedgffr57
#
# 45 <- krmvzbhctztlpfour9fcmdscctdhsf535
#
# 17 <- fbjgdrzxv1four573vljtseven
#
# 89 <- 8three9ngrjrhh
#
# 14 <- 1gqfoneninegzpbjtbd74
#
# 66 <- 6vkf
#
# 91 <- 9eightzmfsbxqttg1one
#
# 59 <- 56k9ninerqprllq
#
# 61 <- jnhlpkbxvm6three6seventwonegp
#
# 99 <- j929
#
# 77 <- sevensixnxgbtfksix5fbdvgkbd77
#
# 31 <- 39sevencpdcbnshpcsevenhggbcthree1znldhfngnk
#
# 64 <- 618fourtzfrql
#
# 29 <- kldcjxktwo5fivetwoninehsbmrgtn
#
# 83 <- msvjzqteightthree3
#
# 21 <- 2xtvr581xsbctkfftjprmb
#
# 78 <- seven13dvstp848dsbllng
#
# 79 <- sevencqhmth7tdshrtrphx9
#
# 36 <- three2eight8six6
#
# 48 <- fourprlhnl7vczqdtl8bjmncrrfpzk
#
# 55 <- 5four1one5
#
# 75 <- seventhreethknine5
#
# 22 <- two6vqgpzvmhlhfourklvxvhmnlqnmrhknstwo
#
# 42 <- 4bvxhmfz2bktbfltj
#
# 99 <- nk9
#
# 79 <- xjb713vmxzcfxl3ninegkjrcq
#
# 89 <- rrmplxeight1znine
#
# 41 <- zsjgngpfourfoureighttwo1
#
# 97 <- 99twojqzlggpseven
#
# 87 <- eightfivetwo7
#
# 89 <- 8ninevlkxsptd2ninenine
#
# 48 <- 4hrzzjxp26sixpxjxphmkpc8
#
# 44 <- vlqsf4ntssmfrz
#
# 86 <- eight93tflqhb9two76six
#
# 49 <- ttxfgqtrfournine9pqqgd
#
# 76 <- 7274mmjgcssvrsix
#
# 16 <- 1threesix5dmkdtjsmptthreeqgfgsix
#
# 23 <- msrtbbschxmvcm2ctprdlnkdzthree
#
# 32 <- dztlvgn3two
#
# 77 <- h7crsblhtp
#
# 72 <- seven5eight7qrgxlninethreetwobbsjdbxcvt
#
# 28 <- 2hfbeight
#
# 81 <- eightrdlfourtwo3vzrlsbcjndnineone
#
# 48 <- ljxbtvhztkkb4three94fiveeight
#
# 32 <- 3fourkbpmpctthreetwovzhgq
#
# 66 <- 6xznbcgdmng
#
# 31 <- 3jl5zlkbjpeight1tvmrqdlk
#
# 26 <- 23sjvtghccsevenninesixzlhgzqtkhb
#
# 34 <- xptf34eightp4cdqcv
#
# 89 <- gfneighthvf3nine
#
# 35 <- threeeightthreenineninethreetwoone5
#
# 92 <- 9nine22qdfzgbdsd7two
#
# 42 <- gfourtwotbxddnxzc2
#
# 44 <- four84gxllvp76four
#
# 86 <- t86
#
# 82 <- nheightwofive525two
#
# 15 <- hh115
#
# 33 <- lqvxpsxthreethreefive34three
#
# 92 <- sgvqhjqdvtzfnine6bgjcbn2tqrvgfmdtdbh
#
# 92 <- nine2seventwop
#
# 72 <- 7hllxxndzggvsrsh9zrktwoone2rxqczzbqpx
#
# 24 <- s2one574
#
# 97 <- 9fourseventzqfseven
#
# 66 <- 62six1jdqcnqm4sixjsjvnx
#
# 53 <- five6fpktwo1l3
#
# 52 <- five1d2
#
# 16 <- fbnoneightknthree6
#
# 46 <- 4fbtxqsix6dxpjclhtlk
#
# 88 <- 8vggprkfjrpqz8hhlvffmfiveone8
#
# 27 <- rz29eightfghseven
#
# 28 <- two9four98cgmntgcncsmppz
#
# 42 <- bmrvhsz4twotwo
#
# 12 <- 1oneeightthreeeightfourtwo
#
# 59 <- fivethreefvz9rzvzdqxqbmtxcnqc
#
# 36 <- 3oneqvseight56lkxjk
#
# 66 <- 6l99six
#
# 78 <- dsevenninefour48kjs
#
# 17 <- 1sixxvrsevenone7
#
# 37 <- lpmdghtcdj3nine28g77glk
#
# 11 <- tnkhrdone1hhtfzhnz
#
# 44 <- 4cpzzht
#
# 41 <- foursixlmtmvrptqonejmssjldcnz8one
#
# 13 <- 1bnd5slzddmkmvthreep4three
#
# 77 <- 7jlrm
#
# 73 <- seventhree3
#
# 64 <- vmjsix8sevenktbrxnftfour
#
# 66 <- gmczxbkcgsixseven6six
#
# 98 <- 9oneone2hhnj8
#
# 84 <- bbpeightjbtp4qfpks2four
#
# 23 <- twoeight3
#
# 74 <- 7mqnzkddm3hrqvhdvzgvgbnfcjtfour
#
# 46 <- 4onesixgkcsix
#
# 11 <- chmkonenine1btgnldh
#
# 85 <- dpxzrthkjzdfkgpkdfvxveight5
#
# 56 <- hxlfiveeight6
#
# 38 <- 3xlkg23fivethreesixeightksmc
#
# 46 <- nfourrjdqx4four6
#
# 34 <- ptzrcdzthreer3phpkqlftwo24
#
# 55 <- five7sevenjpjmmppfive
#
# 15 <- 11sevenfivezcglsdkhqffivethreeseven5
#
# 48 <- 4eight5mjlkzrgnmlnmxntqmtlxmqlkjccttcpmgznfouroneightk
#
# 18 <- 1oneightx
#
# 26 <- 25fivevhtpblpfthreefour2xrzsix
#
# 83 <- eightfour41four8fiveone3
#
# 23 <- pxmrbcqt22vfvzvvp4seven3
#
# 31 <- 3zqbqnnonesxtgz9eightonepqnld
#
# 29 <- d2six5dmlqczzrtp79brzzq
#
# 98 <- nine48
#
# 91 <- ninevbjkjcd11qhtvb
#
# 65 <- six4nine1four2three5
#
# 19 <- lcnvnxgzssonethree5mnvlsevenclrcpxbjbzvhlj9
#
# 81 <- 8onethree6n1
#
# 96 <- 98ddgtwov6nzvjzsscd
#
# 77 <- bklvmzjrqgfqx7
#
# 58 <- 5eight95ninetwo8
#
# 62 <- qcrgbmzlztvtzrsjsixmvps2
#
# 98 <- jsnmkd9seveneight
#
# 26 <- mkdzj28twohhmkctnsix
#
# 33 <- kb38sixttdhv9three
#
# 82 <- 8eightninetwo
#
# 27 <- twoppvc7
#
# 66 <- sixfour5sj6cdfjsskfb
#
# 28 <- 242p28mxh8zrkvzp
#
# 65 <- sixnine5kqqrhxms
#
# 25 <- 21sixfivepmspvnbscjc
#
# 38 <- threetjgcjpvflndq98
#
# 18 <- sgonefivefive8
#
# 93 <- nine5sevenfouronedsqpkgpthbeight3hrfdmcql
#
# 15 <- 1sixkhqpcv5
#
# 13 <- bsnnone3
#
# 47 <- 46sevenbnfsgnjldbtjnsjlmhvjrp8sevenx
#
# 22 <- twotwosevenonelzlpnmkdqq2rqthff
#
# 64 <- sixfournbzqfhff6jdlfhpt974
#
# 52 <- 5sixnvs2trqprv
#
# 91 <- nine8ninefourninelgcxntninektmhgjqrpd1
#
# 24 <- hsjmpqkpkqzjnmgbz2nine6four
#
# 64 <- 6two7jzfivethree25four
#
# 24 <- twobxtwosixfbhj5prfntlmfour
#
# 46 <- 4lfsevenxsvvlmbzcnprsix
#
# 49 <- 45lxtrdvsgfzzcmzjz7ninenvcvc
#
# 39 <- qfzvfthree9
#
# 74 <- sevenlxfzcsevenseven4
#
# 91 <- sjpqvfmx9twonep
#
# 57 <- qsljtpgdprjbkgzcnv5seveneightseven
#
# 33 <- zmhdkvltbxv3qftmt143
#
# 58 <- 5sevennh68
#
# 76 <- sevenfour6rg
#
# 18 <- 1sixonesixfournbbz9hfeight
#
# 71 <- sevensevenfour265one
#
# 82 <- 88sixtwo
#
# 18 <- one5rcczjeightknjeight
#
# 27 <- qgftwohszlmfgjnn7
#
# 37 <- xbtcpx3htlseven
#
# 78 <- 7tnmvjdj4zlltljq8pdlnfghnd
#
# 99 <- jcpcgznmmnine4ninenine
#
# 55 <- zvdsbmlvn5four555
#
# 34 <- threejpnbcbttggm9onefour4vtjhdfjsnz
#
# 77 <- 7x7
#
# 81 <- veightone1
#
# 88 <- eightjlkckhqjfonesix94twoeightvggdqxgcn
#
# 24 <- 2two2fdzkxgfour9sjtfourvxklldpvjm
#
# 85 <- 849ndjngjhs65hgvdbcxps
#
# 55 <- fiveeightsevenseventfqzdxnhxkxgmnqmdjmxmdc35
#
# 44 <- 4sevenqnhvszlfour
#
# 85 <- seightwozbjkfsgk5three1tcpbshgfzeightfive
#
# 44 <- fourgxmqgpgbtwo4
#
# 49 <- 4nine9
#
# 27 <- twokfvsvfgdtmtwom2xlkjseven
#
# 99 <- 9one43ninedrtznff
#
# 57 <- zlfive98rfpmnsevennljlhbxhcn
#
# 78 <- lmfgxfdsevenchrkbhxlrrssbcqqf7fivectglcvrsrg8
#
# 62 <- 6twofive3two
#
# 66 <- mchm6
#
# 33 <- mbvtbcjvv33rqfsllshb
# Extracted : 1000
# Sum of all values : 54249
